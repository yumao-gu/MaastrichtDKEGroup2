# %%
import numpy as np
import math,datetime,sys,torch,time,random,torch,datetime
import multiprocessing as mp
from torch.distributions import uniform, normal
import matplotlib.pyplot as plt
import scipy as sp
from scipy.stats import norm,multivariate_normal
from sklearn.utils import resample

# %%
weights = [1]
means = [[0.]]
covs = [[1.]]
theta_gt = np.array([[0]])
get_data = lambda n: torch.from_numpy(gaussian_mixture_model_sample(n, means, covs, weights, test=False))

# %%
def LogLikelihood(theta, x):

  distribution = torch.distributions.normal.Normal(theta[0, 0], 1)
  log_prob = distribution.log_prob(x)
  
  return log_prob

# %%
def gaussian_mixture_model_sample(n_samples = 10000,
                                  means = [[0.9, -0.8],[-0.7, 0.9]],
                                  covs = [[[2.0, 0.3], [0.3, 0.5]],
                                          [[0.3, 0.5], [0.3, 2.0]]],
                                  weights = [0.3,0.7],
                                  test = False):

  start = time.time()
  dim = len(means[0])
  samples = np.zeros((dim,n_samples))

  for i in range(n_samples):
    r = random.random()
    for j in range(len(weights)):
      if sum(weights[:j+1]) > r:
        samples[:,i] = multivariate_normal.rvs(mean = means[j], cov = covs[j])
        break

  end = time.time()
  print(f'gaussian_mixture_model_sample {end-start}')

  return samples

# %%
def gradient_ascent_torch(func, param , data, max_iterations, learningrate):

  start = time.time()
  for t in range(max_iterations):
    loglikelihoods = func(param, data)
    loglikelihood_value = torch.mean(loglikelihoods)
    param.retain_grad()
    loglikelihood_value.backward()
    with torch.no_grad():
      param.add_(learningrate * param.grad)
      param.grad.zero_()
  
  end = time.time()
  print(f'gradient_ascent_torch {end-start}')

  return param, loglikelihood_value

# %%
def get_derivatives_torch(func, param, data):

  start = time.time()
  func_forScore = lambda args: func(args, data)
  Scores = torch.autograd.functional.jacobian(func_forScore, param).squeeze()

  func_forHessian = lambda args: torch.mean(func(args, data))
  Hessian = torch.autograd.functional.hessian(func_forHessian, param).squeeze()
  end = time.time()
  print(f'get_derivatives_torch {end-start}')

  return Scores, Hessian

# %%
def normal_CI(alpha, Scores, Hessian, theta_n_M):

  start = time.time()
  n = Scores.shape[0]
  z = sp.stats.norm.ppf(1-alpha/2)
  H_n_inv = np.linalg.inv(Hessian.reshape(theta_n_M.shape[1],theta_n_M.shape[1]))
  S_n = 1/n * np.dot(Scores.T, Scores)

  Cov = np.dot(H_n_inv, np.dot(S_n, H_n_inv))
  Cov_diag = np.diag(Cov).reshape(1,-1)
  Cov_diag = np.sqrt(1/n*Cov_diag)

  CI_borders = np.zeros((2, theta_n_M.shape[1]))
  CI_borders[0, :] = theta_n_M - z * Cov_diag ## CI_borders[0, i] = theta_n_M[i] - z*Cov_ii
  CI_borders[1, :] = theta_n_M + z * Cov_diag

  length = CI_borders[1, :] - CI_borders[0, :]
  shape = (CI_borders[1, :] - theta_n_M) / (theta_n_M - CI_borders[0, :])

  end = time.time()
  print(f'normal_CI {end-start}')

  return CI_borders, length, shape

# %%
def GetCI(n,m, alpha, type_CI):
    
  start = time.time()  
  data = get_data(int(n)).cuda()
  theta = torch.tensor([[uniform.Uniform(-2, 2).sample()]], requires_grad=True).cuda()

  theta, _ = gradient_ascent_torch(func=LogLikelihood,
                                                param=theta,
                                                data=data,
                                                max_iterations=5000,
                                                learningrate=0.01)

  if type_CI == 'normal':
    theta_hat = theta.cpu().clone().data.detach().numpy()
    Scores, Hessian = get_derivatives_torch(func=LogLikelihood,
                                            param=theta,
                                            data=data)
    ci, length, shape = normal_CI(alpha, Scores.cpu(), Hessian.cpu(), theta_hat)
  
  end = time.time()
  print(f'GetCI {end-start}')

  return ci, length, shape

# %%
def CISamplingTest(ground_truth,n_power,m,test_num):

  start = time.time()
  result = 0
  length = 0
  shape = 0
  n = math.pow(10,n_power)

  for j in range(test_num):
    print(f'test num {j}')
    ci, lengthCI , shapeCI = GetCI(n,m, alpha=alpha, type_CI=type_CI)
    length += lengthCI.squeeze()
    shape += shapeCI.squeeze()
    if ground_truth >= ci[0] and ground_truth <= ci[1]:
      result += 1
  
  end = time.time()
  print(f'CISamplingTest {end-start}')

  return {n_power: (result/test_num, length/test_num, shape/test_num)}

# %%
alpha = 0.1
type_CI = 'normal'
n_Ci = 100

result = CISamplingTest(theta_gt[0,0],5,1,n_Ci)
print(f'result {result}')
# Out:
# test num 0
# gaussian_mixture_model_sample 9.397291421890259
# gradient_ascent_torch 4.471856117248535
# get_derivatives_torch 44.76304602622986
# normal_CI 0.003711700439453125
# GetCI 69.17248821258545
# test num 1
# gaussian_mixture_model_sample 9.314554214477539
# gradient_ascent_torch 4.4177000522613525
# get_derivatives_torch 45.21180462837219
# normal_CI 0.0008797645568847656
# GetCI 58.947025299072266
# test num 2
# gaussian_mixture_model_sample 9.28926420211792
# gradient_ascent_torch 4.360684633255005
# get_derivatives_torch 45.410457611083984
# normal_CI 0.0006086826324462891
# GetCI 59.063525676727295
# test num 3
# gaussian_mixture_model_sample 9.393657684326172
# gradient_ascent_torch 4.419691801071167
# get_derivatives_torch 45.101698875427246
# normal_CI 0.0005435943603515625
# GetCI 58.91801738739014
# test num 4
# gaussian_mixture_model_sample 9.415627241134644
# gradient_ascent_torch 4.3945395946502686
# get_derivatives_torch 45.18634533882141
# normal_CI 0.0005970001220703125
# GetCI 58.999656438827515
# test num 5
# gaussian_mixture_model_sample 9.428154230117798
# gradient_ascent_torch 4.445307016372681
# get_derivatives_torch 46.83491849899292
# normal_CI 0.0006136894226074219
# GetCI 60.711318016052246
# test num 6
# gaussian_mixture_model_sample 9.37259840965271
# gradient_ascent_torch 4.392494440078735
# get_derivatives_torch 45.50220727920532
# normal_CI 0.0005962848663330078
# GetCI 59.27034330368042
# test num 7
# gaussian_mixture_model_sample 9.250055074691772
# gradient_ascent_torch 4.359076261520386
# get_derivatives_torch 45.19818329811096
# normal_CI 0.0008256435394287109
# GetCI 58.8107225894928
# test num 8
# gaussian_mixture_model_sample 9.333125352859497
# gradient_ascent_torch 4.395247936248779
# get_derivatives_torch 45.005324602127075
# normal_CI 0.0006670951843261719
# GetCI 58.73686218261719
# test num 9
# gaussian_mixture_model_sample 9.283961296081543
# gradient_ascent_torch 4.407899618148804
# get_derivatives_torch 45.20172357559204
# normal_CI 0.0005080699920654297
# GetCI 58.89642024040222
# test num 10
# gaussian_mixture_model_sample 9.316712141036987
# gradient_ascent_torch 4.4351606369018555
# get_derivatives_torch 46.597601890563965
# normal_CI 0.0006806850433349609
# GetCI 60.35258150100708
# test num 11
# gaussian_mixture_model_sample 9.356075286865234
# gradient_ascent_torch 4.3505425453186035
# get_derivatives_torch 44.74116635322571
# normal_CI 0.0005929470062255859
# GetCI 58.45064926147461
# test num 12
# gaussian_mixture_model_sample 9.419875860214233
# gradient_ascent_torch 4.466468811035156
# get_derivatives_torch 45.023584842681885
# normal_CI 0.0006575584411621094
# GetCI 58.912912130355835
# test num 13
# gaussian_mixture_model_sample 9.305623769760132
# gradient_ascent_torch 4.337383031845093
# get_derivatives_torch 45.06852698326111
# normal_CI 0.0005054473876953125
# GetCI 58.71457099914551
# test num 14
# gaussian_mixture_model_sample 9.278432846069336
# gradient_ascent_torch 4.3720457553863525
# get_derivatives_torch 45.21985578536987
# normal_CI 0.0006432533264160156
# GetCI 58.87331557273865
# test num 15
# gaussian_mixture_model_sample 9.31802773475647
# gradient_ascent_torch 4.355566740036011
# get_derivatives_torch 46.35249900817871
# normal_CI 0.0005674362182617188
# GetCI 60.02892565727234
# test num 16
# gaussian_mixture_model_sample 9.452312231063843
# gradient_ascent_torch 4.381816625595093
# get_derivatives_torch 44.6417875289917
# normal_CI 0.0006012916564941406
# GetCI 58.47895789146423
# test num 17
# gaussian_mixture_model_sample 9.362895488739014
# gradient_ascent_torch 4.364154815673828
# get_derivatives_torch 45.14825248718262
# normal_CI 0.0005304813385009766
# GetCI 58.87814903259277
# test num 18
# gaussian_mixture_model_sample 9.225606918334961
# gradient_ascent_torch 4.328207969665527
# get_derivatives_torch 44.70215964317322
# normal_CI 0.0005741119384765625
# GetCI 58.25886392593384
# test num 19
# gaussian_mixture_model_sample 9.141355276107788
# gradient_ascent_torch 4.341790676116943
# get_derivatives_torch 44.318734884262085
# normal_CI 0.0005342960357666016
# GetCI 57.804651975631714
# test num 20
# gaussian_mixture_model_sample 9.158258199691772
# gradient_ascent_torch 4.368215560913086
# get_derivatives_torch 44.58472037315369
# normal_CI 0.0006256103515625
# GetCI 58.11411213874817
# test num 21
# gaussian_mixture_model_sample 9.548299312591553
# gradient_ascent_torch 4.7709691524505615
# get_derivatives_torch 44.925429821014404
# normal_CI 0.0008521080017089844
# GetCI 59.24840211868286
# test num 22
# gaussian_mixture_model_sample 9.358282327651978
# gradient_ascent_torch 4.40890645980835
# get_derivatives_torch 45.687530279159546
# normal_CI 0.0006101131439208984
# GetCI 59.45778298377991
# test num 23
# gaussian_mixture_model_sample 9.32419204711914
# gradient_ascent_torch 4.409368991851807
# get_derivatives_torch 44.74624824523926
# normal_CI 0.0005564689636230469
# GetCI 58.48287105560303
# test num 24
# gaussian_mixture_model_sample 9.231339693069458
# gradient_ascent_torch 4.3661158084869385
# get_derivatives_torch 45.12285017967224
# normal_CI 0.0006396770477294922
# GetCI 58.72331190109253
# test num 25
# gaussian_mixture_model_sample 9.248172044754028
# gradient_ascent_torch 4.368307113647461
# get_derivatives_torch 45.109686613082886
# normal_CI 0.0008099079132080078
# GetCI 58.72915267944336
# test num 26
# gaussian_mixture_model_sample 9.261879444122314
# gradient_ascent_torch 4.365044832229614
# get_derivatives_torch 46.26122331619263
# normal_CI 0.0006279945373535156
# GetCI 59.8911235332489
# test num 27
# gaussian_mixture_model_sample 9.416874647140503
# gradient_ascent_torch 4.410824775695801
# get_derivatives_torch 45.36597967147827
# normal_CI 0.0005443096160888672
# GetCI 59.1965754032135
# test num 28
# gaussian_mixture_model_sample 9.366780281066895
# gradient_ascent_torch 4.3422675132751465
# get_derivatives_torch 44.74766421318054
# normal_CI 0.0006182193756103516
# GetCI 58.459776878356934
# test num 29
# gaussian_mixture_model_sample 9.322681665420532
# gradient_ascent_torch 4.3277201652526855
# get_derivatives_torch 44.888911724090576
# normal_CI 0.0005486011505126953
# GetCI 58.54237341880798
# test num 30
# gaussian_mixture_model_sample 9.27082896232605
# gradient_ascent_torch 4.369551181793213
# get_derivatives_torch 44.84600567817688
# normal_CI 0.0006754398345947266
# GetCI 58.48953199386597
# test num 31
# gaussian_mixture_model_sample 9.349706649780273
# gradient_ascent_torch 4.423698902130127
# get_derivatives_torch 46.015496015548706
# normal_CI 0.0005655288696289062
# GetCI 59.79180836677551
# test num 32
# gaussian_mixture_model_sample 9.167293071746826
# gradient_ascent_torch 4.3748133182525635
# get_derivatives_torch 45.364550828933716
# normal_CI 0.0006091594696044922
# GetCI 58.90988612174988
# test num 33
# gaussian_mixture_model_sample 9.388388872146606
# gradient_ascent_torch 4.305248975753784
# get_derivatives_torch 44.91204905509949
# normal_CI 0.0006923675537109375
# GetCI 58.6088981628418
# test num 34
# gaussian_mixture_model_sample 9.22736382484436
# gradient_ascent_torch 4.349832534790039
# get_derivatives_torch 44.665262937545776
# normal_CI 0.0005862712860107422
# GetCI 58.24569535255432
# test num 35
# gaussian_mixture_model_sample 9.335524082183838
# gradient_ascent_torch 4.436073541641235
# get_derivatives_torch 44.56476616859436
# normal_CI 0.00054931640625
# GetCI 58.33936071395874
# test num 36
# gaussian_mixture_model_sample 9.095845699310303
# gradient_ascent_torch 4.3306944370269775
# get_derivatives_torch 45.55412721633911
# normal_CI 0.0006532669067382812
# GetCI 58.98397493362427
# test num 37
# gaussian_mixture_model_sample 9.326749563217163
# gradient_ascent_torch 4.339737176895142
# get_derivatives_torch 44.60172724723816
# normal_CI 0.0007605552673339844
# GetCI 58.271244287490845
# test num 38
# gaussian_mixture_model_sample 9.349436044692993
# gradient_ascent_torch 4.346182346343994
# get_derivatives_torch 44.64735412597656
# normal_CI 0.0005576610565185547
# GetCI 58.345892667770386
# test num 39
# gaussian_mixture_model_sample 9.24993371963501
# gradient_ascent_torch 4.388205051422119
# get_derivatives_torch 44.92082238197327
# normal_CI 0.0005269050598144531
# GetCI 58.56188154220581
# test num 40
# gaussian_mixture_model_sample 9.233617782592773
# gradient_ascent_torch 4.344050645828247
# get_derivatives_torch 44.79432940483093
# normal_CI 0.0008106231689453125
# GetCI 58.37496876716614
# test num 41
# gaussian_mixture_model_sample 9.243404865264893
# gradient_ascent_torch 4.323169231414795
# get_derivatives_torch 44.75533843040466
# normal_CI 0.0005657672882080078
# GetCI 58.3247549533844
# test num 42
# gaussian_mixture_model_sample 9.263001918792725
# gradient_ascent_torch 4.6525187492370605
# get_derivatives_torch 45.75829195976257
# normal_CI 0.0005152225494384766
# GetCI 59.67666172981262
# test num 43
# gaussian_mixture_model_sample 9.200253248214722
# gradient_ascent_torch 4.392436504364014
# get_derivatives_torch 45.43671464920044
# normal_CI 0.0005841255187988281
# GetCI 59.032302379608154
# test num 44
# gaussian_mixture_model_sample 9.203314542770386
# gradient_ascent_torch 4.354396343231201
# get_derivatives_torch 44.743842124938965
# normal_CI 0.000774383544921875
# GetCI 58.30482625961304
# test num 45
# gaussian_mixture_model_sample 9.190454483032227
# gradient_ascent_torch 4.362295389175415
# get_derivatives_torch 44.6498658657074
# normal_CI 0.0007944107055664062
# GetCI 58.20606327056885
# test num 46
# gaussian_mixture_model_sample 9.162611484527588
# gradient_ascent_torch 4.4188103675842285
# get_derivatives_torch 44.66904926300049
# normal_CI 0.0005526542663574219
# GetCI 58.253241539001465
# test num 47
# gaussian_mixture_model_sample 9.111356258392334
# gradient_ascent_torch 4.3513267040252686
# get_derivatives_torch 46.35015368461609
# normal_CI 0.0005950927734375
# GetCI 59.815690755844116
# test num 48
# gaussian_mixture_model_sample 9.418295621871948
# gradient_ascent_torch 4.398479223251343
# get_derivatives_torch 45.74240446090698
# normal_CI 0.0008425712585449219
# GetCI 59.56242799758911
# test num 49
# gaussian_mixture_model_sample 9.298290014266968
# gradient_ascent_torch 4.36265230178833
# get_derivatives_torch 44.91005802154541
# normal_CI 0.0009634494781494141
# GetCI 58.574209213256836
# test num 50
# gaussian_mixture_model_sample 9.274327516555786
# gradient_ascent_torch 4.4394073486328125
# get_derivatives_torch 45.436049699783325
# normal_CI 0.0005908012390136719
# GetCI 59.15266823768616
# test num 51
# gaussian_mixture_model_sample 9.26647138595581
# gradient_ascent_torch 4.449727535247803
# get_derivatives_torch 44.801302671432495
# normal_CI 0.0005543231964111328
# GetCI 58.52032399177551
# test num 52
# gaussian_mixture_model_sample 9.263993740081787
# gradient_ascent_torch 4.327576637268066
# get_derivatives_torch 46.144415855407715
# normal_CI 0.0008311271667480469
# GetCI 59.738964319229126
# test num 53
# gaussian_mixture_model_sample 9.222303628921509
# gradient_ascent_torch 4.345093011856079
# get_derivatives_torch 44.75853443145752
# normal_CI 0.0006320476531982422
# GetCI 58.32889223098755
# test num 54
# gaussian_mixture_model_sample 9.225769281387329
# gradient_ascent_torch 4.333912372589111
# get_derivatives_torch 44.23229908943176
# normal_CI 0.0005176067352294922
# GetCI 57.79480838775635
# test num 55
# gaussian_mixture_model_sample 9.172114372253418
# gradient_ascent_torch 4.287501096725464
# get_derivatives_torch 44.58999061584473
# normal_CI 0.0005824565887451172
# GetCI 58.05255198478699
# test num 56
# gaussian_mixture_model_sample 9.139389276504517
# gradient_ascent_torch 4.350240468978882
# get_derivatives_torch 44.277817249298096
# normal_CI 0.0007424354553222656
# GetCI 57.770763874053955
# test num 57
# gaussian_mixture_model_sample 9.287358045578003
# gradient_ascent_torch 4.430562973022461
# get_derivatives_torch 44.424952030181885
# normal_CI 0.0007495880126953125
# GetCI 58.14607906341553
# test num 58
# gaussian_mixture_model_sample 9.253788232803345
# gradient_ascent_torch 4.737260818481445
# get_derivatives_torch 44.926175117492676
# normal_CI 0.0007150173187255859
# GetCI 58.92024755477905
# test num 59
# gaussian_mixture_model_sample 9.068057298660278
# gradient_ascent_torch 4.308417558670044
# get_derivatives_torch 44.44375395774841
# normal_CI 0.0005807876586914062
# GetCI 57.82308912277222
# test num 60
# gaussian_mixture_model_sample 9.181021690368652
# gradient_ascent_torch 4.374224901199341
# get_derivatives_torch 44.48409652709961
# normal_CI 0.0008602142333984375
# GetCI 58.042280435562134
# test num 61
# gaussian_mixture_model_sample 9.225666522979736
# gradient_ascent_torch 4.376091480255127
# get_derivatives_torch 45.28676438331604
# normal_CI 0.0006175041198730469
# GetCI 58.89153456687927
# test num 62
# gaussian_mixture_model_sample 9.171648502349854
# gradient_ascent_torch 4.275910377502441
# get_derivatives_torch 44.367544651031494
# normal_CI 0.0006442070007324219
# GetCI 57.81799554824829
# test num 63
# gaussian_mixture_model_sample 9.070942640304565
# gradient_ascent_torch 4.296347141265869
# get_derivatives_torch 45.56477642059326
# normal_CI 0.0007150173187255859
# GetCI 58.9350266456604
# test num 64
# gaussian_mixture_model_sample 9.267593383789062
# gradient_ascent_torch 4.5586888790130615
# get_derivatives_torch 44.07460165023804
# normal_CI 0.0005474090576171875
# GetCI 57.90376353263855
# test num 65
# gaussian_mixture_model_sample 9.099831342697144
# gradient_ascent_torch 4.325565576553345
# get_derivatives_torch 44.451977014541626
# normal_CI 0.0006515979766845703
# GetCI 57.88036036491394
# test num 66
# gaussian_mixture_model_sample 9.043526411056519
# gradient_ascent_torch 4.3140668869018555
# get_derivatives_torch 44.38171315193176
# normal_CI 0.0005640983581542969
# GetCI 57.74216628074646
# test num 67
# gaussian_mixture_model_sample 9.049776077270508
# gradient_ascent_torch 4.285233020782471
# get_derivatives_torch 43.92601704597473
# normal_CI 0.0006008148193359375
# GetCI 57.264068603515625
# test num 68
# gaussian_mixture_model_sample 9.21911358833313
# gradient_ascent_torch 4.346670389175415
# get_derivatives_torch 45.72390031814575
# normal_CI 0.0010304450988769531
# GetCI 59.293001651763916
# test num 69
# gaussian_mixture_model_sample 9.080316305160522
# gradient_ascent_torch 4.284654855728149
# get_derivatives_torch 44.81959939002991
# normal_CI 0.0007152557373046875
# GetCI 58.187664270401
# test num 70
# gaussian_mixture_model_sample 9.085144281387329
# gradient_ascent_torch 4.284947633743286
# get_derivatives_torch 44.061742544174194
# normal_CI 0.0005106925964355469
# GetCI 57.43466901779175
# test num 71
# gaussian_mixture_model_sample 9.218278408050537
# gradient_ascent_torch 4.265323638916016
# get_derivatives_torch 43.86938667297363
# normal_CI 0.0006229877471923828
# GetCI 57.35601091384888
# test num 72
# gaussian_mixture_model_sample 9.08730673789978
# gradient_ascent_torch 4.32116961479187
# get_derivatives_torch 44.11376929283142
# normal_CI 0.0005850791931152344
# GetCI 57.52513909339905
# test num 73
# gaussian_mixture_model_sample 9.01688265800476
# gradient_ascent_torch 4.286705493927002
# get_derivatives_torch 44.29613780975342
# normal_CI 0.0005438327789306641
# GetCI 57.602386474609375
# test num 74
# gaussian_mixture_model_sample 9.13191270828247
# gradient_ascent_torch 4.6951398849487305
# get_derivatives_torch 45.01560997962952
# normal_CI 0.0005781650543212891
# GetCI 58.845820903778076
# test num 75
# gaussian_mixture_model_sample 9.134346723556519
# gradient_ascent_torch 4.380814075469971
# get_derivatives_torch 43.86371350288391
# normal_CI 0.0005230903625488281
# GetCI 57.38165211677551
# test num 76
# gaussian_mixture_model_sample 9.154550313949585
# gradient_ascent_torch 4.308830976486206
# get_derivatives_torch 44.33784890174866
# normal_CI 0.0005328655242919922
# GetCI 57.80409002304077
# test num 77
# gaussian_mixture_model_sample 9.051751375198364
# gradient_ascent_torch 4.30330491065979
# get_derivatives_torch 43.9926233291626
# normal_CI 0.0005316734313964844
# GetCI 57.350430727005005
# test num 78
# gaussian_mixture_model_sample 9.180758953094482
# gradient_ascent_torch 4.261904001235962
# get_derivatives_torch 43.96078181266785
# normal_CI 0.0005445480346679688
# GetCI 57.406418561935425
# test num 79
# gaussian_mixture_model_sample 8.998555183410645
# gradient_ascent_torch 4.268548965454102
# get_derivatives_torch 46.13213777542114
# normal_CI 0.0006282329559326172
# GetCI 59.402238845825195
# test num 80
# gaussian_mixture_model_sample 9.099007606506348
# gradient_ascent_torch 4.362088918685913
# get_derivatives_torch 44.381676197052
# normal_CI 0.0007760524749755859
# GetCI 57.846132040023804
# test num 81
# gaussian_mixture_model_sample 9.072557926177979
# gradient_ascent_torch 4.333683967590332
# get_derivatives_torch 43.92119812965393
# normal_CI 0.0006744861602783203
# GetCI 57.33056902885437
# test num 82
# gaussian_mixture_model_sample 9.089403867721558
# gradient_ascent_torch 4.395933628082275
# get_derivatives_torch 43.88234901428223
# normal_CI 0.0005769729614257812
# GetCI 57.3707058429718
# test num 83
# gaussian_mixture_model_sample 8.980908632278442
# gradient_ascent_torch 4.263888835906982
# get_derivatives_torch 44.059555768966675
# normal_CI 0.0005719661712646484
# GetCI 57.307231426239014
# test num 84
# gaussian_mixture_model_sample 9.016459226608276
# gradient_ascent_torch 4.258656024932861
# get_derivatives_torch 45.15837240219116
# normal_CI 0.0006108283996582031
# GetCI 58.43638062477112
# test num 85
# gaussian_mixture_model_sample 9.241737127304077
# gradient_ascent_torch 4.2768049240112305
# get_derivatives_torch 44.367881059646606
# normal_CI 0.0005366802215576172
# GetCI 57.889214754104614
# test num 86
# gaussian_mixture_model_sample 9.087114810943604
# gradient_ascent_torch 4.311120271682739
# get_derivatives_torch 44.30605387687683
# normal_CI 0.0006034374237060547
# GetCI 57.70719838142395
# test num 87
# gaussian_mixture_model_sample 9.01060938835144
# gradient_ascent_torch 4.316378593444824
# get_derivatives_torch 44.18620538711548
# normal_CI 0.0005245208740234375
# GetCI 57.51594424247742
# test num 88
# gaussian_mixture_model_sample 9.044567346572876
# gradient_ascent_torch 4.2982563972473145
# get_derivatives_torch 43.86582040786743
# normal_CI 0.0006051063537597656
# GetCI 57.21152949333191
# test num 89
# gaussian_mixture_model_sample 9.139726638793945
# gradient_ascent_torch 4.399438142776489
# get_derivatives_torch 44.065670013427734
# normal_CI 0.0005691051483154297
# GetCI 57.60771465301514
# test num 90
# gaussian_mixture_model_sample 9.131143808364868
# gradient_ascent_torch 4.296108961105347
# get_derivatives_torch 46.26623606681824
# normal_CI 0.0005593299865722656
# GetCI 59.69646143913269
# test num 91
# gaussian_mixture_model_sample 9.149052858352661
# gradient_ascent_torch 4.263622283935547
# get_derivatives_torch 44.533822774887085
# normal_CI 0.0008072853088378906
# GetCI 57.949814558029175
# test num 92
# gaussian_mixture_model_sample 9.184808254241943
# gradient_ascent_torch 4.30686616897583
# get_derivatives_torch 44.53385376930237
# normal_CI 0.0007607936859130859
# GetCI 58.02862811088562
# test num 93
# gaussian_mixture_model_sample 9.177874326705933
# gradient_ascent_torch 4.3795554637908936
# get_derivatives_torch 44.5615508556366
# normal_CI 0.001043558120727539
# GetCI 58.12227725982666
# test num 94
# gaussian_mixture_model_sample 9.206628561019897
# gradient_ascent_torch 4.3398966789245605
# get_derivatives_torch 44.68308615684509
# normal_CI 0.0005788803100585938
# GetCI 58.23236036300659
# test num 95
# gaussian_mixture_model_sample 9.119075775146484
# gradient_ascent_torch 4.337512016296387
# get_derivatives_torch 46.58187961578369
# normal_CI 0.0005695819854736328
# GetCI 60.04139304161072
# test num 96
# gaussian_mixture_model_sample 9.262524843215942
# gradient_ascent_torch 4.3683247566223145
# get_derivatives_torch 44.50973868370056
# normal_CI 0.0006148815155029297
# GetCI 58.143718957901
# test num 97
# gaussian_mixture_model_sample 9.168885707855225
# gradient_ascent_torch 4.377076148986816
# get_derivatives_torch 44.818384408950806
# normal_CI 0.0005643367767333984
# GetCI 58.36711931228638
# test num 98
# gaussian_mixture_model_sample 9.171802520751953
# gradient_ascent_torch 4.285083532333374
# get_derivatives_torch 44.56071901321411
# normal_CI 0.0007474422454833984
# GetCI 58.02094841003418
# test num 99
# gaussian_mixture_model_sample 9.220744609832764
# gradient_ascent_torch 4.318220376968384
# get_derivatives_torch 44.273454904556274
# normal_CI 0.0005238056182861328
# GetCI 57.815117835998535
# CISamplingTest 5858.76867723465
# result {5: (0.92, 0.01040438273638794, 1.0)}
